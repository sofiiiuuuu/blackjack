# %% [markdown]
# | Function Name     | Description                                                     | Input Parameters                | Return Value                |
# |-------------------|-----------------------------------------------------------------|--------------------------------|-----------------------------|
# |card_deck()| Creates the 52-card deck using a Tuple| none                           | tuple (the deck)           |
# | check_points()    | Calculates and returns the total points of a hand               | list of cards so  list[int]      | int (total points)         |
# | check_game()      | Decides if the player wins, loses, or continues                 | int (points)                   | string (game state)        |
# | borrow()          | Lets the player draw new cards until they stop or game ends     | tuple deck, int points         | int (updated points)       |
# |player_hand()| has the value that the player has right now, can change| list of current cards so list(cards)| Lets the player play the cards they have, it changes. |In and out of list|
# |main()| Executes teh action of the whole program in one function|none|string and int(all_functions)|
# |rounds()|Executes rounds one using a loop function, than acumulates teh points of all rounds|loop, repetition|int(los puntos al final de la partida)|
# |determine_winner()|Compare points and prints results to decide winner| player_hand(list) and dealer hand(list)|none, prints the winner with reasult|
# dealer_turn()| draws cards until getting at least 17 points| deck(list) and dealer_hand()| updated dealer hand (list)|
# |aces()|ver si A da 11 o 1 (dependiendo de lo mas conveniente)|total(int)|new_total(int)|
# |shuffle()|randomixe card|none|deck(list)|using random to move the list in random order|

# %% [markdown]
# Reflection:
# - I think my peers did a great job understanding tuples and lists. i think we all understood when to use each and why. Being that the main difference is taht lists can add and subtract values while in tuples they are fixed and you cannot. That is why for the deck we all used tupple.
#
# - I got that my functions were very basic, which looking back is true. I missed a lot of the specificity that I needed in order to complete the game. However in this new version I think I improved a lot.
#
# - I subtracted a function that was not adding much to my code, I also added more functions like shuffle and dealer hand which will help me do my code later.
#
# - It makes it more organized, I have more functions which also makes more readible and easier to debug.
